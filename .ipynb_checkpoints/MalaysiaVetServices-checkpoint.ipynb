# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Izzah Alia\anaconda3\python.exe

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\izzah alia\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\izzah alia\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\izzah alia\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\izzah alia\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\izzah alia\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplot lib
# Out:
# Requirement already satisfied: matplot in c:\users\izzah alia\anaconda3\lib\site-packages (0.1.9)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: lib in c:\users\izzah alia\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: pyloco>=0.0.134 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplot) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\izzah alia\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: ushlex in c:\users\izzah alia\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in c:\users\izzah alia\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (1.8.0)
# Requirement already satisfied: twine in c:\users\izzah alia\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (5.1.1)
# Requirement already satisfied: typing in c:\users\izzah alia\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: SimpleWebSocketServer in c:\users\izzah alia\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\izzah alia\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.10.0)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: requests>=2.20 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.32.2)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (24.3.1)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.3.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\izzah alia\anaconda3\lib\site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Requirement already satisfied: jaraco.classes in c:\users\izzah alia\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.2)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\izzah alia\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.2.18)
# Requirement already satisfied: docutils>=0.21.2 in c:\users\izzah alia\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.21.2)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\izzah alia\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\izzah alia\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\izzah alia\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.7.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\izzah alia\anaconda3\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\izzah alia\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.0)
# Requirement already satisfied: more-itertools in c:\users\izzah alia\anaconda3\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.1.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
vet = pd.read_csv('data/registeredvet.csv')

# %%
vet.head(2)
# Out:
#    Bil                  Nama Klinik  \
# 0    1       KELAB LUMBA KUDA PERAK
# 1    2  KLINIK HAIWAN & SURGERI GOH
#
#                                   Alamat Premis 1   Alamat Premis 2   Poskod  \
# 0  RACECOURSE JALAN RAJA DI HILIR (JALAN TAMBUN),               NaN  30350.0
# 1                       NO. 1, SELASAR WAH KEONG,  TAMAN WAH KEONG,  31400.0
#
#   Daerah Negeri               No. Telefon         Fax  \
# 0  IPOH,  Perak   05-2549076 / 05-2542237  05-2531355
# 1  IPOH,  Perak  05-5454880 / 012-5013880           -
#
#                         Email   No. Lesen Kelas Lesen   Tujuan Kegunaan  \
# 0  prtcequinehosp@hotmail.com  KKM/R/0447           C  MENSTOR MENGGUNA
# 1                           -  KKM/R/0293           C  MENSTOR MENGGUNA
#
#    Sektor
# 0  Swasta
# 1  Swasta

# %%
vet.head(5)
# Out:
#    Bil                          Nama Klinik  \
# 0    1               KELAB LUMBA KUDA PERAK
# 1    2          KLINIK HAIWAN & SURGERI GOH
# 2    3          IPOH EAST VETERINARY CLINIC
# 3    4                          ZOO TAIPING
# 4    5  IPOH GARDEN ANIMAL CLINIC SDN. BHD.
#
#                                   Alamat Premis 1     Alamat Premis 2  \
# 0  RACECOURSE JALAN RAJA DI HILIR (JALAN TAMBUN),                 NaN
# 1                       NO. 1, SELASAR WAH KEONG,    TAMAN WAH KEONG,
# 2                         62, LALUAN PERAJURIT 1,   TAMAN IPOH TIMOR,
# 3                                     ZOO TAIPING  JALAN TAMAN TASIK,
# 4                       NO. 30, PESARA IPOH SATU,        IPOH GARDEN,
#
#     Poskod    Daerah Negeri                No. Telefon         Fax  \
# 0  30350.0     IPOH,  Perak    05-2549076 / 05-2542237  05-2531355
# 1  31400.0     IPOH,  Perak   05-5454880 / 012-5013880           -
# 2  31400.0     IPOH,  Perak                 05-5469927  04-6586052
# 3  34000.0  TAIPING,  Perak  05-8086577 / 019-550 9314           -
# 4  31400.0     IPOH,  Perak                 05-5455933           -
#
#                         Email   No. Lesen Kelas Lesen   Tujuan Kegunaan  \
# 0  prtcequinehosp@hotmail.com  KKM/R/0447           C  MENSTOR MENGGUNA
# 1                           -  KKM/R/0293           C  MENSTOR MENGGUNA
# 2      gilbert01png@gmail.com  KKM/R/0826           C           MENSTOR
# 3   drkevin@zootaiping.gov.my  KKM/R/0849           C           MENSTOR
# 4          igac30@hotmail.com  KKM/R/0775           C  MENSTOR MENGGUNA
#
#    Sektor
# 0  Swasta
# 1  Swasta
# 2     NaN
# 3  Swasta
# 4  Swasta

# %%
vet = vet.drop(0, axis=0)

# %%
vet.head(5)
# Out:
#    Bil                          Nama Klinik            Alamat Premis 1  \
# 1    2          KLINIK HAIWAN & SURGERI GOH  NO. 1, SELASAR WAH KEONG,
# 2    3          IPOH EAST VETERINARY CLINIC    62, LALUAN PERAJURIT 1,
# 3    4                          ZOO TAIPING                ZOO TAIPING
# 4    5  IPOH GARDEN ANIMAL CLINIC SDN. BHD.  NO. 30, PESARA IPOH SATU,
# 5    6                MAXWELL ANIMAL CLINIC   NO. 9, LORONG KILANG 3A,
#
#       Alamat Premis 2   Poskod    Daerah Negeri                No. Telefon  \
# 1    TAMAN WAH KEONG,  31400.0     IPOH,  Perak   05-5454880 / 012-5013880
# 2   TAMAN IPOH TIMOR,  31400.0     IPOH,  Perak                 05-5469927
# 3  JALAN TAMAN TASIK,  34000.0  TAIPING,  Perak  05-8086577 / 019-550 9314
# 4        IPOH GARDEN,  31400.0     IPOH,  Perak                 05-5455933
# 5    OFF JALAN TUPAI,  34000.0  TAIPING,  Perak                 05-8071669
#
#           Fax                      Email   No. Lesen Kelas Lesen  \
# 1           -                          -  KKM/R/0293           C
# 2  04-6586052     gilbert01png@gmail.com  KKM/R/0826           C
# 3           -  drkevin@zootaiping.gov.my  KKM/R/0849           C
# 4           -         igac30@hotmail.com  KKM/R/0775           C
# 5           -       ongteikwah@yahoo.com  KKM/R/0818           C
#
#     Tujuan Kegunaan  Sektor
# 1  MENSTOR MENGGUNA  Swasta
# 2           MENSTOR     NaN
# 3           MENSTOR  Swasta
# 4  MENSTOR MENGGUNA  Swasta
# 5           MENSTOR  Swasta

# %%
# Remove the comma from the 'Daerah' column
vet['Daerah'] = vet['Daerah'].str.strip(',')

# %%
vet.head(5)
# Out:
#    Bil                          Nama Klinik            Alamat Premis 1  \
# 1    2          KLINIK HAIWAN & SURGERI GOH  NO. 1, SELASAR WAH KEONG,
# 2    3          IPOH EAST VETERINARY CLINIC    62, LALUAN PERAJURIT 1,
# 3    4                          ZOO TAIPING                ZOO TAIPING
# 4    5  IPOH GARDEN ANIMAL CLINIC SDN. BHD.  NO. 30, PESARA IPOH SATU,
# 5    6                MAXWELL ANIMAL CLINIC   NO. 9, LORONG KILANG 3A,
#
#       Alamat Premis 2   Poskod   Daerah Negeri                No. Telefon  \
# 1    TAMAN WAH KEONG,  31400.0     IPOH  Perak   05-5454880 / 012-5013880
# 2   TAMAN IPOH TIMOR,  31400.0     IPOH  Perak                 05-5469927
# 3  JALAN TAMAN TASIK,  34000.0  TAIPING  Perak  05-8086577 / 019-550 9314
# 4        IPOH GARDEN,  31400.0     IPOH  Perak                 05-5455933
# 5    OFF JALAN TUPAI,  34000.0  TAIPING  Perak                 05-8071669
#
#           Fax                      Email   No. Lesen Kelas Lesen  \
# 1           -                          -  KKM/R/0293           C
# 2  04-6586052     gilbert01png@gmail.com  KKM/R/0826           C
# 3           -  drkevin@zootaiping.gov.my  KKM/R/0849           C
# 4           -         igac30@hotmail.com  KKM/R/0775           C
# 5           -       ongteikwah@yahoo.com  KKM/R/0818           C
#
#     Tujuan Kegunaan  Sektor
# 1  MENSTOR MENGGUNA  Swasta
# 2           MENSTOR     NaN
# 3           MENSTOR  Swasta
# 4  MENSTOR MENGGUNA  Swasta
# 5           MENSTOR  Swasta

# %%
vet['Daerah'] = vet['Daerah'].str[0].str.upper() + vet['Daerah'].str[1:].str.lower()

# %%
vet.head(5)
# Out:
#    Bil                          Nama Klinik            Alamat Premis 1  \
# 1    2          KLINIK HAIWAN & SURGERI GOH  NO. 1, SELASAR WAH KEONG,
# 2    3          IPOH EAST VETERINARY CLINIC    62, LALUAN PERAJURIT 1,
# 3    4                          ZOO TAIPING                ZOO TAIPING
# 4    5  IPOH GARDEN ANIMAL CLINIC SDN. BHD.  NO. 30, PESARA IPOH SATU,
# 5    6                MAXWELL ANIMAL CLINIC   NO. 9, LORONG KILANG 3A,
#
#       Alamat Premis 2   Poskod   Daerah Negeri                No. Telefon  \
# 1    TAMAN WAH KEONG,  31400.0     Ipoh  Perak   05-5454880 / 012-5013880
# 2   TAMAN IPOH TIMOR,  31400.0     Ipoh  Perak                 05-5469927
# 3  JALAN TAMAN TASIK,  34000.0  Taiping  Perak  05-8086577 / 019-550 9314
# 4        IPOH GARDEN,  31400.0     Ipoh  Perak                 05-5455933
# 5    OFF JALAN TUPAI,  34000.0  Taiping  Perak                 05-8071669
#
#           Fax                      Email   No. Lesen Kelas Lesen  \
# 1           -                          -  KKM/R/0293           C
# 2  04-6586052     gilbert01png@gmail.com  KKM/R/0826           C
# 3           -  drkevin@zootaiping.gov.my  KKM/R/0849           C
# 4           -         igac30@hotmail.com  KKM/R/0775           C
# 5           -       ongteikwah@yahoo.com  KKM/R/0818           C
#
#     Tujuan Kegunaan  Sektor
# 1  MENSTOR MENGGUNA  Swasta
# 2           MENSTOR     NaN
# 3           MENSTOR  Swasta
# 4  MENSTOR MENGGUNA  Swasta
# 5           MENSTOR  Swasta

# %%
vet.shape
# Out:
# (92, 14)

# %%
vet['Negeri'].value_counts()
# Out:
# Negeri
# Selangor                35
# Wilayah Persekutuan     18
# Perak                    7
# Johor                    7
# Pulau Pinang             7
# Sabah                    6
# Sarawak                  6
# Melaka                   2
# Negeri Sembilan          2
# Pahang                   1
# Kelantan                 1
# Name: count, dtype: int64

# %%
vet.isnull().sum()
# Out:
# Bil                 0
# Nama Klinik         0
# Alamat Premis 1     0
# Alamat Premis 2    12
# Poskod              1
# Daerah              1
# Negeri              0
# No. Telefon         1
# Fax                 2
# Email               0
# No. Lesen           0
# Kelas Lesen         0
# Tujuan Kegunaan     0
# Sektor              1
# dtype: int64

# %%
vet.duplicated().sum()
# Out:
# 0

# %%
if 'USJ ANIMAL CLINIC (SUBANG JAYA)' in vet['Nama Klinik'].values:
    # Get the row(s) where 'Nama Kilinik' is 'USJ ANIMAL CLINIC (SUBANG JAYA)'
    rows = vet[vet['Nama Klinik'] == 'USJ ANIMAL CLINIC (SUBANG JAYA)']
    
    # Add the 'Daerah' value for those rows
    vet.loc[rows.index, 'Daerah'] = 'Subang Jaya'

# %%
vet.isnull().sum()
# Out:
# Bil                 0
# Nama Klinik         0
# Alamat Premis 1     0
# Alamat Premis 2    12
# Poskod              1
# Daerah              0
# Negeri              0
# No. Telefon         1
# Fax                 2
# Email               0
# No. Lesen           0
# Kelas Lesen         0
# Tujuan Kegunaan     0
# Sektor              1
# dtype: int64

# %%
if 'IPOH EAST VETERINARY CLINIC' in vet['Nama Klinik'].values:
    rows = vet[vet['Nama Klinik'] == 'IPOH EAST VETERINARY CLINIC']
    vet.loc[rows.index, 'Sektor'] = 'Swasta'

# %%
vet.isnull().sum()
# Out:
# Bil                 0
# Nama Klinik         0
# Alamat Premis 1     0
# Alamat Premis 2    12
# Poskod              1
# Daerah              0
# Negeri              0
# No. Telefon         1
# Fax                 2
# Email               0
# No. Lesen           0
# Kelas Lesen         0
# Tujuan Kegunaan     0
# Sektor              0
# dtype: int64

# %%
vet = vet.drop("Alamat Premis 2", axis=1)

# %%
vet.isnull().sum()
# Out:
# Bil                0
# Nama Klinik        0
# Alamat Premis 1    0
# Poskod             1
# Daerah             0
# Negeri             0
# No. Telefon        1
# Fax                2
# Email              0
# No. Lesen          0
# Kelas Lesen        0
# Tujuan Kegunaan    0
# Sektor             0
# dtype: int64

# %%
if 'HOSPITAL VETERINAR UNIVERSITI (UPM)' in vet['Nama Klinik'].values:
    rows = vet[vet['Nama Klinik'] == 'HOSPITAL VETERINAR UNIVERSITI (UPM)']
    vet.loc[rows.index, 'Poskod'] = '43400'
# Out:
# C:\Users\Izzah Alia\AppData\Local\Temp\ipykernel_13808\1827494921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '43400' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   vet.loc[rows.index, 'Poskod'] = '43400'

# %%
vet.isnull().sum()
# Out:
# Bil                0
# Nama Klinik        0
# Alamat Premis 1    0
# Poskod             0
# Daerah             0
# Negeri             0
# No. Telefon        1
# Fax                2
# Email              0
# No. Lesen          0
# Kelas Lesen        0
# Tujuan Kegunaan    0
# Sektor             0
# dtype: int64

# %%
vet = vet.drop("Fax", axis=1)

# %%
vet.isnull().sum()
# Out:
# Bil                0
# Nama Klinik        0
# Alamat Premis 1    0
# Poskod             0
# Daerah             0
# Negeri             0
# No. Telefon        1
# Email              0
# No. Lesen          0
# Kelas Lesen        0
# Tujuan Kegunaan    0
# Sektor             0
# dtype: int64

# %%
if 'ARK VETERINARY CENTRE' in vet['Nama Klinik'].values:
    rows = vet[vet['Nama Klinik'] == 'ARK VETERINARY CENTRE']
    vet.loc[rows.index, 'No. Telefon'] = '03-7726 7405'

# %%
vet.isnull().sum()
# Out:
# Bil                0
# Nama Klinik        0
# Alamat Premis 1    0
# Poskod             0
# Daerah             0
# Negeri             0
# No. Telefon        1
# Email              0
# No. Lesen          0
# Kelas Lesen        0
# Tujuan Kegunaan    0
# Sektor             0
# dtype: int64

# %%
if 'KLINIK HAIWAN VET PARTNERS' in vet['Nama Klinik'].values:
    rows = vet[vet['Nama Klinik'] == 'KLINIK HAIWAN VET PARTNERS']
    vet.loc[rows.index, 'No. Telefon'] = '018-776 2218'

# %%
vet.isnull().sum()
# Out:
# Bil                0
# Nama Klinik        0
# Alamat Premis 1    0
# Poskod             0
# Daerah             0
# Negeri             0
# No. Telefon        0
# Email              0
# No. Lesen          0
# Kelas Lesen        0
# Tujuan Kegunaan    0
# Sektor             0
# dtype: int64

# %%
if 'HOSPITAL VETERINAR KUALA LUMPUR' in vet['Nama Klinik'].values:
    rows = vet[vet['Nama Klinik'] == 'HOSPITAL VETERINAR KUALA LUMPUR']
    vet.loc[rows.index, 'No. Telefon'] = '03-9200 2890'

# %%
vet.head(100)
# Out:
#     Bil                                        Nama Klinik  \
# 1     2                        KLINIK HAIWAN & SURGERI GOH
# 2     3                        IPOH EAST VETERINARY CLINIC
# 3     4                                        ZOO TAIPING
# 4     5                IPOH GARDEN ANIMAL CLINIC SDN. BHD.
# 5     6                              MAXWELL ANIMAL CLINIC
# ..  ...                                                ...
# 88   89  JABATAN PERLINDUNGAN HIDUPAN LIAR DAN TAMAN NE...
# 89   90  JABATAN PERKHIDMATAN HAIWAN & PERUSAHAN TERNAK...
# 90   91    JABATAN PERKHIDMATAN HAIWAN WILAYAH PERSEKUTUAN
# 91   92                    HOSPITAL VETERINAR KUALA LUMPUR
# 92   93  JABATAN PERLINDUNGAN HIDUPAN LIAR & TAMAN NEGA...
#
#                                      Alamat Premis 1   Poskod         Daerah  \
# 1                          NO. 1, SELASAR WAH KEONG,  31400.0           Ipoh
# 2                            62, LALUAN PERAJURIT 1,  31400.0           Ipoh
# 3                                        ZOO TAIPING  34000.0        Taiping
# 4                          NO. 30, PESARA IPOH SATU,  31400.0           Ipoh
# 5                           NO. 9, LORONG KILANG 3A,  34000.0        Taiping
# ..                                               ...      ...            ...
# 88  PUSAT MENYELAMAT HIDUPAN LIAR KEBANGSAAN SUNGKAI  35600.0        Sungkai
# 89                                   JALAN PAHLAWAN,  88200.0  Kota kinabalu
# 90   JABATAN PERKHIDMATAN HAIWAN WILAYAH PERSEKUTUAN  56100.0   kuala lumpur
# 91                 JABATAN PERKHIDMATAN VETERINAR WP  56100.0   Kuala lumpur
# 92               KOMPLEKS PANDA, ZOO NEGARA MALAYSIA  68000.0    Hulu kelang
#
#                   Negeri                  No. Telefon  \
# 1                  Perak     05-5454880 / 012-5013880
# 2                  Perak                   05-5469927
# 3                  Perak    05-8086577 / 019-550 9314
# 4                  Perak                   05-5455933
# 5                  Perak                   05-8071669
# ..                   ...                          ...
# 88                 Perak                  012-9571971
# 89                 Sabah                   088-251233
# 90  Wilayah Persekutuan   03-9284 9716 / 03-9284 9718
# 91  Wilayah Persekutuan                  03-9200 2890
# 92  Wilayah Persekutuan   03-9086 6835 / 03-9086 6800
#
#                                                 Email   No. Lesen Kelas Lesen  \
# 1                                                   -  KKM/R/0293           C
# 2                              gilbert01png@gmail.com  KKM/R/0826           C
# 3                           drkevin@zootaiping.gov.my  KKM/R/0849           C
# 4                                  igac30@hotmail.com  KKM/R/0775           C
# 5                                ongteikwah@yahoo.com  KKM/R/0818           C
# ..                                                ...         ...         ...
# 88  sitiaminah@wildlife.gov.my; zubaidah@wildlife....         T/B           C
# 89                                                  -         T/B         A&C
# 90                                                  -         T/B           C
# 91                                                  -         T/B           C
# 92                             inirah@wildlife.gov.my         T/B         A&C
#
#      Tujuan Kegunaan    Sektor
# 1   MENSTOR MENGGUNA    Swasta
# 2            MENSTOR    Swasta
# 3            MENSTOR    Swasta
# 4   MENSTOR MENGGUNA    Swasta
# 5            MENSTOR    Swasta
# ..               ...       ...
# 88  MENSTOR MENGGUNA  Kerajaan
# 89  MENSTOR MENGGUNA  Kerajaan
# 90  MENSTOR MENGGUNA  Kerajaan
# 91  MENSTOR MENGGUNA  Kerajaan
# 92  MENSTOR MENGGUNA  Kerajaan
#
# [92 rows x 12 columns]

# %%
vet['Negeri'].value_counts()
# Out:
# Negeri
# Selangor                35
# Wilayah Persekutuan     18
# Perak                    7
# Johor                    7
# Pulau Pinang             7
# Sabah                    6
# Sarawak                  6
# Melaka                   2
# Negeri Sembilan          2
# Pahang                   1
# Kelantan                 1
# Name: count, dtype: int64

# %%
vet['Daerah'].value_counts()
# Out:
# Daerah
# Kuala lumpur       15
# Petaling jaya       8
# Puchong             6
# Kota kinabalu       5
# Ipoh                4
# Klang               4
# Seri kembangan      3
# Kuching             3
# Kajang              3
# Pulau pinang        2
# Johor bahru         2
# Taiping             2
# Melaka              2
# Skudai              2
# Subang jaya         2
#  kuala lumpur       2
# Sungai nibong       1
# Gelugor             1
# Masai               1
# Senawang            1
# Seremban            1
# Tanjung bungah      1
# Butterworth         1
# Kluang              1
# Batu pahat          1
# Sungkai             1
# Tanjung tokong      1
# Miri                1
# Bintulu             1
# Sibu                1
# Tuaran              1
# Kota bharu          1
# Kuantan             1
# Rawang              1
# Sungai buloh        1
# Shah alam           1
# Batu caves          1
# Uep subang jaya     1
# Subang Jaya         1
# Serdang             1
# Ampang              1
# Cheras              1
# Hulu kelang         1
# Name: count, dtype: int64
